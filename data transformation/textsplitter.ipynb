# %%
from langchain_community.document_loaders import TextLoader

loder = TextLoader('demo.txt')
loder

# %%
text_documents = loder.load()
text_documents
# Out:
# [Document(metadata={'source': 'demo.txt'}, page_content='LangChain is an open-source framework that simplifies building applications with Large Language Models (LLMs) by providing tools to connect them to data and other services, allowing for complex, context-aware AI tools like chatbots, data analysis, and agents that can reason and use external tools. It acts as a bridge, offering modular components and abstractions to chain LLMs with data sources (APIs, databases, documents) and processing steps, making AI development faster and more powerful. \nThis video provides a brief overview of what LangChain is:\n\nKey Features & Functions\nData Integration: Connects LLMs to external data (PDFs, databases, web pages) for context beyond their training data.\nChains & Agents: Enables creating multi-step workflows (chains) and autonomous agents that can use tools and make decisions.\nPrompt Management: Offers tools for structuring, optimizing, and managing prompts for better model output.\nModular Components: Provides reusable building blocks (models, document loaders, vector stores) for flexible application development.\nObservability: Integrates with platforms like LangSmith for tracing and debugging agent behavior. \nWhat it helps developers do\nBuild context-aware chatbots that remember past conversations.\nCreate research tools that summarize information from multiple documents.\nDevelop automated data analysis and business process applications.\nIntegrate LLMs into existing applications for enhanced capabilities. \n')]

# %% [markdown]
# How to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_documents = text_splitter.split_documents(text_documents)
final_documents
# Out:
# [Document(metadata={'source': 'demo.txt'}, page_content='LangChain is an open-source framework that simplifies building applications with Large Language Models (LLMs) by providing tools to connect them to data and other services, allowing for complex, context-aware AI tools like chatbots, data analysis, and agents that can reason and use external tools. It acts as a bridge, offering modular components and abstractions to chain LLMs with data sources (APIs, databases, documents) and processing steps, making AI development faster and more powerful.'),
#  Document(metadata={'source': 'demo.txt'}, page_content='This video provides a brief overview of what LangChain is:'),
#  Document(metadata={'source': 'demo.txt'}, page_content='Key Features & Functions\nData Integration: Connects LLMs to external data (PDFs, databases, web pages) for context beyond their training data.\nChains & Agents: Enables creating multi-step workflows (chains) and autonomous agents that can use tools and make decisions.\nPrompt Management: Offers tools for structuring, optimizing, and managing prompts for better model output.'),
#  Document(metadata={'source': 'demo.txt'}, page_content='Modular Components: Provides reusable building blocks (models, document loaders, vector stores) for flexible application development.\nObservability: Integrates with platforms like LangSmith for tracing and debugging agent behavior. \nWhat it helps developers do\nBuild context-aware chatbots that remember past conversations.\nCreate research tools that summarize information from multiple documents.\nDevelop automated data analysis and business process applications.'),
#  Document(metadata={'source': 'demo.txt'}, page_content='Integrate LLMs into existing applications for enhanced capabilities.')]

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='LangChain is an open-source framework that simplifies building applications with Large Language Models (LLMs) by providing tools to connect them to data and other services, allowing for complex, context-aware AI tools like chatbots, data analysis, and agents that can reason and use external tools. It acts as a bridge, offering modular components and abstractions to chain LLMs with data sources (APIs, databases, documents) and processing steps, making AI development faster and more powerful.' metadata={'source': 'demo.txt'}
# page_content='This video provides a brief overview of what LangChain is:' metadata={'source': 'demo.txt'}

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader('speech.txt')
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.\n\nJust because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\n…\n\nIt will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and fairness because we act without animus, not in enmity toward a people or with the desire to bring any injury or disadvantage upon them, but only in armed opposition to an irresponsible government which has thrown aside all considerations of humanity and of right and is running amuck. We are, let me say again, the sincere friends of the German people, and shall desire nothing so much as the early reestablishment of intimate relations of mutual advantage between us—however hard it may be for them, for the time being, to believe that this is spoken from our hearts.\n\nWe have borne with their present government through all these bitter months because of that friendship—exercising a patience and forbearance which would otherwise have been impossible. We shall, happily, still have an opportunity to prove that friendship in our daily attitude and actions toward the millions of men and women of German birth and native sympathy who live among us and share our life, and we shall be proud to prove it toward all who are in fact loyal to their neighbors and to the government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without countenance except from a lawless and malignant few.\n\nIt is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of all wars, civilization itself seeming to be in the balance. But the right is more precious than peace, and we shall fight for the things which we have always carried nearest our hearts—for democracy, for the right of those who submit to authority to have a voice in their own governments, for the rights and liberties of small nations, for a universal dominion of right by such a concert of free peoples as shall bring peace and safety to all nations and make the world itself at last free.\n\nTo such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
speech=""
with open("speech.txt") as f:
    speech = f.read()
speech

text_splitter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=20)
text = text_splitter.create_documents([speech])

print(text)
print(text[0])
print(text[1])
print(text[2])
# Out:
# [Document(metadata={}, page_content='The world must be made safe for democracy. Its'), Document(metadata={}, page_content='for democracy. Its peace must be planted upon the'), Document(metadata={}, page_content='be planted upon the tested foundations of'), Document(metadata={}, page_content='foundations of political liberty. We have no'), Document(metadata={}, page_content='liberty. We have no selfish ends to serve. We'), Document(metadata={}, page_content='ends to serve. We desire no conquest, no'), Document(metadata={}, page_content='no conquest, no dominion. We seek no indemnities'), Document(metadata={}, page_content='seek no indemnities for ourselves, no material'), Document(metadata={}, page_content='no material compensation for the sacrifices we'), Document(metadata={}, page_content='the sacrifices we shall freely make. We are but'), Document(metadata={}, page_content='make. We are but one of the champions of the'), Document(metadata={}, page_content='champions of the rights of mankind. We shall be'), Document(metadata={}, page_content='We shall be satisfied when those rights have been'), Document(metadata={}, page_content='rights have been made as secure as the faith and'), Document(metadata={}, page_content='as the faith and the freedom of nations can make'), Document(metadata={}, page_content='of nations can make them.'), Document(metadata={}, page_content='Just because we fight without rancor and without'), Document(metadata={}, page_content='rancor and without selfish object, seeking'), Document(metadata={}, page_content='object, seeking nothing for ourselves but what we'), Document(metadata={}, page_content='but what we shall wish to share with all free'), Document(metadata={}, page_content='share with all free peoples, we shall, I feel'), Document(metadata={}, page_content='we shall, I feel confident, conduct our'), Document(metadata={}, page_content='conduct our operations as belligerents without'), Document(metadata={}, page_content='without passion and ourselves observe with proud'), Document(metadata={}, page_content='observe with proud punctilio the principles of'), Document(metadata={}, page_content='the principles of right and of fair play we'), Document(metadata={}, page_content='and of fair play we profess to be fighting for.'), Document(metadata={}, page_content='…'), Document(metadata={}, page_content='It will be all the easier for us to conduct'), Document(metadata={}, page_content='for us to conduct ourselves as belligerents in a'), Document(metadata={}, page_content='belligerents in a high spirit of right and'), Document(metadata={}, page_content='spirit of right and fairness because we act'), Document(metadata={}, page_content='because we act without animus, not in enmity'), Document(metadata={}, page_content='not in enmity toward a people or with the desire'), Document(metadata={}, page_content='or with the desire to bring any injury or'), Document(metadata={}, page_content='bring any injury or disadvantage upon them, but'), Document(metadata={}, page_content='upon them, but only in armed opposition to an'), Document(metadata={}, page_content='opposition to an irresponsible government which'), Document(metadata={}, page_content='government which has thrown aside all'), Document(metadata={}, page_content='thrown aside all considerations of humanity and'), Document(metadata={}, page_content='of humanity and of right and is running amuck. We'), Document(metadata={}, page_content='running amuck. We are, let me say again, the'), Document(metadata={}, page_content='me say again, the sincere friends of the German'), Document(metadata={}, page_content='of the German people, and shall desire nothing so'), Document(metadata={}, page_content='desire nothing so much as the early'), Document(metadata={}, page_content='much as the early reestablishment of intimate'), Document(metadata={}, page_content='of intimate relations of mutual advantage between'), Document(metadata={}, page_content='advantage between us— ...
# page_content='The world must be made safe for democracy. Its'
# page_content='for democracy. Its peace must be planted upon the'
# page_content='be planted upon the tested foundations of'
