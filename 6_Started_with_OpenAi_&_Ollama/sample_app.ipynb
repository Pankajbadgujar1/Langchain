# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
## Data Ingestion--From the website we need to scrape the data
from langchain_community.document_loaders import WebBaseLoader

# %%
loader=WebBaseLoader("https://docs.smith.langchain.com/tutorials/Administrators/manage_spend")
loader

# %%
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': '\uf8ffü¶úÔ∏è\uf8ffüõ†Ô∏è LangSmith', 'language': 'en'}, page_content='\n\n\n\n\n\uf8ffü¶úÔ∏è\uf8ffüõ†Ô∏è LangSmith\n\n\n\n\n\n\n\n\nSkip to main contentLangSmith docs have moved! Find the LangSmith docs at the new LangChain Docs site.API ReferenceRESTPythonJS/TSSearchRegionUSEUGo to AppPage Not FoundWe could not find what you were looking for.Head back to our main docs page or use the search bar to find the page you need.CommunityLangChain ForumTwitterGitHubDocs CodeLangSmith SDKPythonJS/TSMoreHomepageBlogLangChain Python DocsLangChain JS/TS DocsCopyright ¬© 2026 LangChain, Inc.\n\n')]

# %%
### Load Data--> Docs-->Divide our Docuemnts into chunks dcouments-->text-->vectors-->Vector Embeddings--->Vector Store DB
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
documents=text_splitter.split_documents(docs)
print(documents)
# Out:
# [Document(metadata={'source': 'https://docs.smith.langchain.com/tutorials/Administrators/manage_spend', 'title': '\uf8ffü¶úÔ∏è\uf8ffüõ†Ô∏è LangSmith', 'language': 'en'}, page_content='\uf8ffü¶úÔ∏è\uf8ffüõ†Ô∏è LangSmith\n\n\n\n\n\n\n\n\nSkip to main contentLangSmith docs have moved! Find the LangSmith docs at the new LangChain Docs site.API ReferenceRESTPythonJS/TSSearchRegionUSEUGo to AppPage Not FoundWe could not find what you were looking for.Head back to our main docs page or use the search bar to find the page you need.CommunityLangChain ForumTwitterGitHubDocs CodeLangSmith SDKPythonJS/TSMoreHomepageBlogLangChain Python DocsLangChain JS/TS DocsCopyright ¬© 2026 LangChain, Inc.')]

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings

embeddings =(
    OllamaEmbeddings(model="llama3.2:latest") ## By default it use llama2
)
db=FAISS.from_documents(docs, embeddings)
db

# %%
## Query From a vector db
query="LangSmith has two usage limits: total traces and extended"
result=db.similarity_search(query)
result[0].page_content
# Out:
# '\n\n\n\n\n\uf8ffü¶úÔ∏è\uf8ffüõ†Ô∏è LangSmith\n\n\n\n\n\n\n\n\nSkip to main contentLangSmith docs have moved! Find the LangSmith docs at the new LangChain Docs site.API ReferenceRESTPythonJS/TSSearchRegionUSEUGo to AppPage Not FoundWe could not find what you were looking for.Head back to our main docs page or use the search bar to find the page you need.CommunityLangChain ForumTwitterGitHubDocs CodeLangSmith SDKPythonJS/TSMoreHomepageBlogLangChain Python DocsLangChain JS/TS DocsCopyright ¬© 2026 LangChain, Inc.\n\n'

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:latest")

# %%
# Out:
# Python running from: d:\Protuple_project_2026\Langchain\venv\python.exe
# Requirement already satisfied: langchain in d:\protuple_project_2026\langchain\venv\lib\site-packages (1.2.6)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\protuple_project_2026\langchain\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\protuple_project_2026\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\panka\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\panka\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.4.0)
# Requirement already satisfied: certifi in c:\users\panka\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\panka\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: idna in c:\users\panka\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\panka\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\panka\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\panka\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\protuple_project_2026\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\protuple_project_2026\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\panka\appdata\roaming\python\python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\protuple_project_2026\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.3.0)

# %%
## Retrieval Chain, Document chain

from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_template(
"""
Answer the following question based only on the provided context:
<context>
{context}
</context>

"""
)
document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 ## Retrieval Chain, Document chain
# ----> 3 from langchain.chains.combine_documents import create_stuff_documents_chain
#       4 from langchain_core.prompts import ChatPromptTemplate
#       6 prompt=ChatPromptTemplate.from_template(
#       7 """
#       8 Answer the following question based only on the provided context:
#    (...)     13 """
#      14 )
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
from langchain_core.documents import Document
document_chain.invoke({
    "input":"LangSmith has two usage limits: total traces and extended",
    "context":[Document(page_content="LangSmith has two usage limits: total traces and extended traces. These correspond to the two metrics we've been tracking on our usage graph. ")]
})
